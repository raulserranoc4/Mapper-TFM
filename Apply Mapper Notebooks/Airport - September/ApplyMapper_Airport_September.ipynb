# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import kmapper as km
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from scipy.stats import iqr
import networkx as nx
import hdbscan
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df_departures = pd.read_pickle("../../calculated_distances_dep.pkl")

df_arrivals = pd.read_pickle("../../calculated_distances_arr.pkl")

print("Columns all:")
print(df_departures.columns.tolist())
# Out:
# Columns all:
# ['airportCode', 'date', 'deviation', 'delay']

# %%
df_arrivals_long_delay = df_arrivals[df_arrivals['delay'] < -500]
print(df_arrivals_long_delay)
# Out:
#        airportCode       date    deviation       delay
# 565414        LEAB 2018-09-22  1943.935833 -556.766667

# %%
# Filter month july

df_departures = df_departures[df_departures['date'].dt.month == 9]

df_arrivals = df_arrivals[df_arrivals['date'].dt.month == 9]

# %%
df_dep_by_airport = df_departures.groupby(['airportCode']).agg({
    'deviation': ['mean', 'median', 'std', iqr],
    'delay': ['mean', 'median', 'std', iqr]
}).reset_index()

df_dep_by_airport.columns = ['airportCode',
                            'deviation_mean', 'deviation_median', 'deviation_std', 'deviation_iqr',
                            'delay_mean', 'delay_median', 'delay_std', 'delay_iqr']

df_arr_by_airport = df_arrivals.groupby(['airportCode']).agg({
    'deviation': ['mean', 'median', 'std', iqr],
    'delay': ['mean', 'median', 'std', iqr]
}).reset_index()


df_arr_by_airport.columns = ['airportCode',
                            'deviation_mean', 'deviation_median', 'deviation_std', 'deviation_iqr',
                            'delay_mean', 'delay_median', 'delay_std', 'delay_iqr']

df_all_by_airport = pd.merge(df_dep_by_airport, df_arr_by_airport, on=['airportCode'], suffixes=('_dep', '_arr'))



print(df_all_by_airport.head())

print(df_all_by_airport.shape)
# Out:
#   airportCode  deviation_mean_dep  deviation_median_dep  deviation_std_dep  \
# 0        GCFV         2247.864230           1376.539917        2425.443093
# 1        GCGM          282.319974            216.027961         306.986730
# 2        GCHI          326.796128            295.394316         184.500126
# 3        GCLA          759.228638            254.125631        1461.587546
# 4        GCLP         1519.831758            580.158551        2192.275720
#
#    deviation_iqr_dep  delay_mean_dep  delay_median_dep  delay_std_dep  \
# 0        2420.088327       -2.853712         -3.800000      11.628027
# 1         308.878570       -8.571311        -10.125000       9.564408
# 2         147.500077       -4.176563         -5.366667       7.675587
# 3         289.740574       -2.780854         -3.766667       8.046601
# 4        2041.182234       -0.791912         -1.875000      11.276672
#
#    delay_iqr_dep  deviation_mean_arr  deviation_median_arr  deviation_std_arr  \
# 0      14.166667         3024.280232           3644.752277        2595.318583
# 1       9.358333          751.930372            717.792200         245.346839
# 2       8.458333          650.689919            520.166304         572.239986
# 3       8.308333          409.445348            148.309357         729.339244
# 4      12.700000         1442.058358           1019.556495        1394.899717
#
#    deviation_iqr_arr  delay_mean_arr  delay_median_arr  delay_std_arr  \
# 0        4915.132739       -1.909357         -2.941667       9.876092
# 1         270.045886      -20.840515        -21.700000       7.554221
# 2         616.889028       -2.027634         -2.700000       7.559429
# 3         269.035155       -1.643264         -2.900000       7.937470
# 4        1387.582303        1.110811         -0.266667      13.676658
#
#    delay_iqr_arr
# 0      10.833333
# 1       8.850000
# 2       8.633333
# 3       8.683333
# 4      15.433333
# (45, 17)

# %%
df_dep_by_airport.fillna({'deviation_std': 0.0, 'delay_std': 0.0}, inplace=True)
print(df_dep_by_airport.isna().sum())

print()
df_arr_by_airport.fillna({'deviation_std': 0.0, 'delay_std': 0.0}, inplace=True)
print(df_arr_by_airport.isna().sum())


print()
df_all_by_airport.fillna({'deviation_std_dep': 0.0, 'delay_std_dep': 0.0, 'deviation_std_arr': 0.0, 'delay_std_arr': 0.0}, inplace=True)
print(df_all_by_airport.isna().sum())
# Out:
# airportCode         0
# deviation_mean      0
# deviation_median    0
# deviation_std       0
# deviation_iqr       0
# delay_mean          0
# delay_median        0
# delay_std           0
# delay_iqr           0
# dtype: int64
#
# airportCode         0
# deviation_mean      0
# deviation_median    0
# deviation_std       0
# deviation_iqr       0
# delay_mean          0
# delay_median        0
# delay_std           0
# delay_iqr           0
# dtype: int64
#
# airportCode             0
# deviation_mean_dep      0
# deviation_median_dep    0
# deviation_std_dep       0
# deviation_iqr_dep       0
# delay_mean_dep          0
# delay_median_dep        0
# delay_std_dep           0
# delay_iqr_dep           0
# deviation_mean_arr      0
# deviation_median_arr    0
# deviation_std_arr       0
# deviation_iqr_arr       0
# delay_mean_arr          0
# delay_median_arr        0
# delay_std_arr           0
# delay_iqr_arr           0
# dtype: int64

# %%
df_numeric = df_all_by_airport.drop(columns=['airportCode'])

corr_matrix = df_numeric.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation matrix between deviations and delays.")
plt.show()

# %%
df_spanish_airports = pd.read_pickle('../../spanish_airports.pkl')

X_all = df_all_by_airport.drop(columns=['airportCode']).dropna()

print(X_all.head())
print()

scaler = StandardScaler()
X_scaled_all = scaler.fit_transform(X_all)

custom_tooltips_all = np.array([
     f"{df_spanish_airports.loc[df_spanish_airports['ICAO'] == row['airportCode'], 'Aeropuerto'].values[0] }" for _, row in df_all_by_airport.iterrows()
])

print(X_scaled_all)
# Out:
#    deviation_mean_dep  deviation_median_dep  deviation_std_dep  \
# 0         2247.864230           1376.539917        2425.443093
# 1          282.319974            216.027961         306.986730
# 2          326.796128            295.394316         184.500126
# 3          759.228638            254.125631        1461.587546
# 4         1519.831758            580.158551        2192.275720
#
#    deviation_iqr_dep  delay_mean_dep  delay_median_dep  delay_std_dep  \
# 0        2420.088327       -2.853712         -3.800000      11.628027
# 1         308.878570       -8.571311        -10.125000       9.564408
# 2         147.500077       -4.176563         -5.366667       7.675587
# 3         289.740574       -2.780854         -3.766667       8.046601
# 4        2041.182234       -0.791912         -1.875000      11.276672
#
#    delay_iqr_dep  deviation_mean_arr  deviation_median_arr  deviation_std_arr  \
# 0      14.166667         3024.280232           3644.752277        2595.318583
# 1       9.358333          751.930372            717.792200         245.346839
# 2       8.458333          650.689919            520.166304         572.239986
# 3       8.308333          409.445348            148.309357         729.339244
# 4      12.700000         1442.058358           1019.556495        1394.899717
#
#    deviation_iqr_arr  delay_mean_arr  delay_median_arr  delay_std_arr  \
# 0        4915.132739       -1.909357         -2.941667       9.876092
# 1         270.045886      -20.840515        -21.700000       7.554221
# 2         616.889028       -2.027634         -2.700000       7.559429
# 3         269.035155       -1.643264         -2.900000       7.937470
# 4        1387.582303        1.110811         -0.266667      13.676658
#
#    delay_iqr_arr
# 0      10.833333
# 1       8.850000
# 2       8.633333
# 3       8.683333
# 4      15.433333
#    1.81531979e-01  6.12414780e-02 -2.87916024e-01 -2.80980206e-01]
#  [-3.02904825e-01 -2.87458697e-01  1.08147600e-01 -2.62234649e-01
#   -6.99043361e-01 -5.43566782e-02  2.32266131e+00  6.10428154e-01
#   -2.26698046e-01 -3.98661882e-01  6.67790432e-01 -3.17317833e-01
#    1.03665272e-01  3.15676317e-01  1.15235698e+00  8.95056686e-01]
#  [ 1.17952919e+00  9.06732565e-01  1.16943127e+00  3.76808707e-01
#    5.14579689e-01  4.00252608e-01 -1.58955197e-01 -1.64728045e-01
#    2.85544105e-01  2.99342745e-01 -2.56835787e-01  5.56349757e-03
#   -1.20902265e-01 -2.86690501e-01 -4.09973229e-01 -1.89637535e-01]
#  [-6.81320198e-01 -6.93624443e-01  3.24191504e-01 -3.58822553e-01
#    9.61149077e-01  6.60390144e-01 -5.70859544e-02 -1.23134297e-01
#   -8.31819477e-01 -7.69969403e-01 -8.65467417e-01 -7.26095912e-01
#    2.47048961e-01  2.51301237e-01 -4.90825119e-01 -5.85455777e-01]
#  [-2.26738624e-01 -2.30864231e-01 -2.22646766e-01  4.57987869e-01
#    6.77044050e-01  4.10355036e-01 -4.71695133e-01 -3.77234280e-01
#   -4.94978487e-01 -4.24745169e-01 -3.87472054e-01  8.28016559e-02
#    2.77740873e-01  2.37506577e-01 -2.58105266e-01 -5.15426395e-01]
#  [ 9.01160484e-01  8.08952629e-01  1.95773106e+00  6.21774715e-01
#    1.50610406e-01  1.69159554e-01  7.58887495e-01  1.83903182e-01
#    6.38179495e-01  4.13676726e-01  4.44665294e-01  3.28846378e-01
#    2.12928465e-01  1.50140398e-01  1.81125249e-01  2.70120577e-01]
#  [ 7.84513003e-01  7.80993970e-01  1.14226193e-01  7.60743890e-01
#    6.26449339e-01  3.58580090e-01 -1.15441979e-02 -2.51696789e-01
#    7.70859452e-01  6.82696252e-01  2.96498191e+00  4.18111691e-01
#    3.11337577e-01  1.71598758e-01 -5.74570536e-02 -2.07144880e-01]]

# %%
def graph_stats(graph):
    G = nx.Graph()
    for node_id in graph['nodes'].keys():
        members = graph['nodes'][node_id]
        nombres_miembros = [custom_tooltips_all[i] for i in members]
        G.add_node(node_id, members=nombres_miembros)
    
    for source, targets in graph['links'].items():
        for target in targets:
            G.add_edge(source, target)

    num_nodos = len(graph['nodes'])
    num_enlaces = len(graph['links'])
    densidad = (2 * num_enlaces) / (num_nodos * (num_nodos - 1)) if num_nodos > 1 else 0
    grados = dict(G.degree()).values()
    grado_medio = sum(grados) / len(grados) if len(grados) > 0 else 0
    grado_max = max(grados) if grados else 0
    grado_min = min(grados) if grados else 0
    num_componentes = nx.number_connected_components(G)
    tamaños = [ len(data['members']) 
            for _, data in G.nodes(data=True) ]
    
    tamaño_medio = sum(tamaños) / len(tamaños)
    diametro = nx.diameter(G) if nx.is_connected(G) else max(nx.diameter(G.subgraph(c)) for c in nx.connected_components(G))
    coef_agrupamiento = nx.average_clustering(G) if len(G) > 1 else 0

    centralidad_grado = nx.degree_centrality(G)
    centralidad_betweenness = nx.betweenness_centrality(G)

    print("Número de nodos:", num_nodos)
    print("Número de enlaces:", num_enlaces)
    print("Densidad del grafo:", densidad)
    print("Grados:", grados)
    print("Grado medio de los nodos:", grado_medio)
    print("Grado máximo:", grado_max)
    print("Grado mínimo:", grado_min)
    print("Número de componentes conectados:", num_componentes)
    print("Tamaño medio de cluster:", tamaño_medio)
    print("Tamaños:", tamaños)
    print("Diámetro del grafo:", diametro)
    print("Coeficiente medio de agrupamiento:", coef_agrupamiento)
    print("Centralidad grado:", centralidad_grado)
    print("Centralidad betweeness:", centralidad_betweenness)
    print()
    print("-" * 30)

    for node_id, data in G.nodes(data=True):
        if(data and data['members']):    
            members = data['members']
            cluster_size = len(members)
            print(f"Clúster: {node_id}")
            print(f" - Número de miembros: {cluster_size}")
            print(f" - Miembros: {[str(member) for member in members]}")
            print("-" * 30)
            
    from collections import defaultdict

    apariciones_miembro = defaultdict(int)

    for _, data in G.nodes(data=True):
        if data and 'members' in data:
            for miembro in data['members']:
                apariciones_miembro[miembro] += 1

    print("\nNúmero de nodos en los que aparece cada miembro:")
    for miembro, conteo in apariciones_miembro.items():
        if conteo > 1:
            print(f" - {miembro}: {conteo} nodos")   
    nx.draw(G, with_labels=True, node_color='skyblue', node_size=500, font_size=12, font_weight='bold')
    
    plt.show()

# %%
mapper = km.KeplerMapper()

pca = PCA(n_components=3)
filter_values_all = pca.fit_transform(X_scaled_all)

pca = PCA(n_components=1)

projection_all = pca.fit_transform(X_scaled_all)
 
graph_all = mapper.map(projection_all,
                       filter_values_all, 
                    clusterer=DBSCAN(eps=2.5, min_samples=1),
                    cover=km.Cover(n_cubes=12, perc_overlap=0.25)
)

color_values_all = X_scaled_all[:, :16]
color_function_name_all = X_all.columns[:16]

mapper.visualize(graph_all, 
                 path_html="mapper_output_all.html", 
                 custom_tooltips=custom_tooltips_all,
                 color_values=color_values_all,
                 color_function_name=color_function_name_all,
                 node_color_function=["mean", "std"])

graph_stats(graph_all)
# Out:
# Número de nodos: 21
# Número de enlaces: 10
# Densidad del grafo: 0.047619047619047616
# Grados: dict_values([0, 1, 1, 1, 2, 1, 2, 1, 0, 0, 2, 0, 2, 2, 1, 1, 1, 1, 1, 0, 0])
# Grado medio de los nodos: 0.9523809523809523
# Grado máximo: 2
# Grado mínimo: 0
# Número de componentes conectados: 11
# Tamaño medio de cluster: 3.0476190476190474
# Tamaños: [1, 2, 2, 3, 7, 1, 11, 1, 1, 1, 8, 2, 9, 8, 1, 1, 1, 1, 1, 1, 1]
# Diámetro del grafo: 6
# Coeficiente medio de agrupamiento: 0.0
# Centralidad grado: {'cube0_cluster0': 0.0, 'cube1_cluster0': 0.05, 'cube2_cluster0': 0.05, 'cube3_cluster0': 0.05, 'cube4_cluster0': 0.1, 'cube4_cluster1': 0.05, 'cube5_cluster0': 0.1, 'cube5_cluster1': 0.05, 'cube5_cluster2': 0.0, 'cube5_cluster3': 0.0, 'cube6_cluster0': 0.1, 'cube6_cluster1': 0.0, 'cube7_cluster0': 0.1, 'cube8_cluster0': 0.1, 'cube8_cluster1': 0.05, 'cube9_cluster0': 0.05, 'cube9_cluster1': 0.05, 'cube9_cluster2': 0.05, 'cube10_cluster0': 0.05, 'cube10_cluster1': 0.0, 'cube11_cluster0': 0.0}
# Centralidad betweeness: {'cube0_cluster0': 0.0, 'cube1_cluster0': 0.0, 'cube2_cluster0': 0.0, 'cube3_cluster0': 0.0, 'cube4_cluster0': 0.02631578947368421, 'cube4_cluster1': 0.0, 'cube5_cluster0': 0.042105263157894736, 'cube5_cluster1': 0.0, 'cube5_cluster2': 0.0, 'cube5_cluster3': 0.0, 'cube6_cluster0': 0.04736842105263158, 'cube6_cluster1': 0.0, 'cube7_cluster0': 0.042105263157894736, 'cube8_cluster0': 0.02631578947368421, 'cube8_cluster1': 0.0, 'cube9_cluster0': 0.0, 'cube9_cluster1': 0.0, 'cube9_cluster2': 0.0, 'cube10_cluster0': 0.0, 'cube10_cluster1': 0.0, 'cube11_cluster0': 0.0}
#
# ------------------------------
# Clúster: cube0_cluster0
#  - Número de miembros: 1
#  - Miembros: ['La Gomera']
# ------------------------------
# Clúster: cube1_cluster0
#  - Número de miembros: 2
#  - Miembros: ['El Hierro – Los Cangrejos', 'La Palma – Mazo']
# ------------------------------
# Clúster: cube2_cluster0
#  - Número de miembros: 2
#  - Miembros: ['La Palma – Mazo', 'Tenerife Norte – Los Rodeos']
# ------------------------------
# Clúster: cube3_cluster0
#  - Número de miembros: 3
#  - Miembros: ['Melilla', 'Burgos – Villafría/Gamonal', 'Sabadell']
# ------------------------------
# Clúster: cube4_cluster0
#  - Número de miembros: 7
#  - Miembros: ['Melilla', 'Badajoz – Talavera la Real', 'La Coruña – Alvedro', 'Sabadell', 'Logroño-Agoncillo', 'San Sebastián', 'Vigo – Peinador']
# ------------------------------
# Clúster: cube4_cluster1
#  - Número de miembros: 1
#  - Miembros: ['Córdoba']
# ------------------------------
# Clúster: cube5_cluster0
#  - Número de miembros: 11
#  - Miembros: ['Gran Canaria – Gando, Las Palmas', 'Asturias', 'Badajoz – Talavera la Real', 'Federico García Lorca Granada-Jaén', 'Menorca', 'Pamplona – Noain', 'Logroño-Agoncillo', 'Reus', 'Santiago de Compostela – Lavacolla', 'Vigo – Peinador', 'Santander – Parayas']
# ------------------------------
# Clúster: cube5_cluster1
#  - Número de miembros: 1
#  - Miembros: ['Córdoba']
# ------------------------------
# Clúster: cube5_cluster2
#  - Número de miembros: 1
#  - Miembros: ['Salamanca – Matacán']
# ------------------------------
# Clúster: cube5_cluster3
#  - Número de miembros: 1
#  - Miembros: ['Mallorca – Son Bonet']
# ------------------------------
# Clúster: cube6_cluster0
#  - Número de miembros: 8
#  - Miembros: ['Lanzarote – Arrecife, Guacimeta, San Bartolomé', 'Asturias', 'Bilbao – La Paloma', 'Gerona-Costa Brava – Girona', 'Murcia-San Javier', 'Madrid-Barajas', 'Reus', 'Valencia – Manises']
# ------------------------------
# Clúster: cube6_cluster1
#  - Número de miembros: 2
#  - Miembros: ['León – Virgen del Camino', 'Valladolid – Villanubla']
# ------------------------------
# Clúster: cube7_cluster0
#  - Número de miembros: 9
#  - Miembros: ['Alicante – El Altet', 'Barcelona – El Prat', 'Gerona-Costa Brava – Girona', 'Ibiza – Es Codolar', 'Jerez – La Parra', 'Murcia-San Javier', 'Madrid-Barajas', 'Palma de Mallorca – Son Sant Joan', 'Vitoria – Foronda']
# ------------------------------
# Clúster: cube8_cluster0
#  - Número de miembros: 8
#  - Miembros: ['Tenerife Sur', 'Alicante – El Altet', 'Barcelona – El Prat', 'Ibiza – Es Codolar', 'Jerez – La Parra', 'Málaga', 'Zaragoza', 'Sevilla – San Pablo']
# ------------------------------
# Clúster: cube8_cluster1
#  - Número de miembros: 1
#  - Miembros: ['Huesca-Pirineos Monflorite']
# ------------------------------
# Clúster: cube9_cluster0
#  - Número de miembros: 1
#  - Miembros: ['Fuerteventura – Puerto del Rosario, Los Matorrales']
# ------------------------------
# Clúster: cube9_cluster1
#  - Número de miembros: 1
#  - Miembros: ['Huesca-Pirineos Monflorite']
# ------------------------------
# Clúster: cube9_cluster2
#  - Número de miembros: 1
#  - Miembros: ['Málaga']
# ------------------------------
# Clúster: cube10_cluster0
#  - Número de miembros: 1
#  - Miembros: ['Fuerteventura – Puerto del Rosario, Los Matorrales']
# ------------------------------
# Clúster: cube10_cluster1
#  - Número de miembros: 1
#  - Miembros: ['Almería']
# ------------------------------
# Clúster: cube11_cluster0
#  - Número de miembros: 1
#  - Miembros: ['Albacete – Los Llanos']
# ------------------------------
#
# Número de nodos en los que aparece cada miembro:
#  - La Palma – Mazo: 2 nodos
#  - Melilla: 2 nodos
#  - Sabadell: 2 nodos
#  - Badajoz – Talavera la Real: 2 nodos
#  - Logroño-Agoncillo: 2 nodos
#  - Vigo – Peinador: 2 nodos
#  - Córdoba: 2 nodos
#  - Asturias: 2 nodos
#  - Reus: 2 nodos
#  - Gerona-Costa Brava – Girona: 2 nodos
#  - Murcia-San Javier: 2 nodos
#  - Madrid-Barajas: 2 nodos
#  - Alicante – El Altet: 2 nodos
#  - Barcelona – El Prat: 2 nodos
#  - Ibiza – Es Codolar: 2 nodos
#  - Jerez – La Parra: 2 nodos
#  - Málaga: 2 nodos
#  - Huesca-Pirineos Monflorite: 2 nodos
#  - Fuerteventura – Puerto del Rosario, Los Matorrales: 2 nodos

# %%
clusterer_all_ = hdbscan.HDBSCAN(min_cluster_size=2, min_samples=1)

graph_all_ = mapper.map(projection_all,
                         filter_values_all,
                         clusterer=clusterer_all_,
                         cover=km.Cover(n_cubes=7, perc_overlap=0.25)
)

mapper.visualize(graph_all_, 
                 path_html="mapper_output_all_.html",
                 custom_tooltips=custom_tooltips_all,
                 color_values=color_values_all,
                 color_function_name=color_function_name_all,
                 node_color_function=["mean", "std"])

graph_stats(graph_all_)
# Out:
# Número de nodos: 12
# Número de enlaces: 3
# Densidad del grafo: 0.045454545454545456
# Grados: dict_values([0, 1, 0, 1, 1, 1, 0, 0, 1, 1, 0, 0])
# Grado medio de los nodos: 0.5
# Grado máximo: 1
# Grado mínimo: 0
# Número de componentes conectados: 9
# Tamaño medio de cluster: 2.5
# Tamaños: [3, 2, 3, 4, 2, 2, 3, 3, 2, 2, 2, 2]
# Diámetro del grafo: 1
# Coeficiente medio de agrupamiento: 0.0
# Centralidad grado: {'cube2_cluster0': 0.0, 'cube2_cluster1': 0.09090909090909091, 'cube3_cluster0': 0.0, 'cube3_cluster1': 0.09090909090909091, 'cube3_cluster2': 0.09090909090909091, 'cube3_cluster3': 0.09090909090909091, 'cube3_cluster4': 0.0, 'cube4_cluster0': 0.0, 'cube4_cluster1': 0.09090909090909091, 'cube4_cluster2': 0.09090909090909091, 'cube4_cluster3': 0.0, 'cube4_cluster4': 0.0}
# Centralidad betweeness: {'cube2_cluster0': 0.0, 'cube2_cluster1': 0.0, 'cube3_cluster0': 0.0, 'cube3_cluster1': 0.0, 'cube3_cluster2': 0.0, 'cube3_cluster3': 0.0, 'cube3_cluster4': 0.0, 'cube4_cluster0': 0.0, 'cube4_cluster1': 0.0, 'cube4_cluster2': 0.0, 'cube4_cluster3': 0.0, 'cube4_cluster4': 0.0}
#
# ------------------------------
# Clúster: cube2_cluster0
#  - Número de miembros: 3
#  - Miembros: ['Melilla', 'Sabadell', 'San Sebastián']
# ------------------------------
# Clúster: cube2_cluster1
#  - Número de miembros: 2
#  - Miembros: ['La Coruña – Alvedro', 'Vigo – Peinador']
# ------------------------------
# Clúster: cube3_cluster0
#  - Número de miembros: 3
#  - Miembros: ['León – Virgen del Camino', 'Mallorca – Son Bonet', 'Valladolid – Villanubla']
# ------------------------------
# Clúster: cube3_cluster1
#  - Número de miembros: 4
#  - Miembros: ['Federico García Lorca Granada-Jaén', 'Menorca', 'Pamplona – Noain', 'Vigo – Peinador']
# ------------------------------
# Clúster: cube3_cluster2
#  - Número de miembros: 2
#  - Miembros: ['Gerona-Costa Brava – Girona', 'Madrid-Barajas']
# ------------------------------
# Clúster: cube3_cluster3
#  - Número de miembros: 2
#  - Miembros: ['Bilbao – La Paloma', 'Murcia-San Javier']
# ------------------------------
# Clúster: cube3_cluster4
#  - Número de miembros: 3
#  - Miembros: ['Asturias', 'Reus', 'Santander – Parayas']
# ------------------------------
# Clúster: cube4_cluster0
#  - Número de miembros: 3
#  - Miembros: ['Lanzarote – Arrecife, Guacimeta, San Bartolomé', 'Tenerife Sur', 'Ibiza – Es Codolar']
# ------------------------------
# Clúster: cube4_cluster1
#  - Número de miembros: 2
#  - Miembros: ['Bilbao – La Paloma', 'Murcia-San Javier']
# ------------------------------
# Clúster: cube4_cluster2
#  - Número de miembros: 2
#  - Miembros: ['Gerona-Costa Brava – Girona', 'Madrid-Barajas']
# ------------------------------
# Clúster: cube4_cluster3
#  - Número de miembros: 2
#  - Miembros: ['Barcelona – El Prat', 'Jerez – La Parra']
# ------------------------------
# Clúster: cube4_cluster4
#  - Número de miembros: 2
#  - Miembros: ['Alicante – El Altet', 'Palma de Mallorca – Son Sant Joan']
# ------------------------------
#
# Número de nodos en los que aparece cada miembro:
#  - Vigo – Peinador: 2 nodos
#  - Gerona-Costa Brava – Girona: 2 nodos
#  - Madrid-Barajas: 2 nodos
#  - Bilbao – La Paloma: 2 nodos
#  - Murcia-San Javier: 2 nodos

# %%
def get_airports_from_graph(graph, nodes=None):
    airports = set()
    if nodes is not None:
        for node_id in graph['nodes'].keys():
            members = graph['nodes'][node_id]
            if len(members) >= nodes:
                nombres_miembros = [custom_tooltips_all[i] for i in members]
                airports.update(nombres_miembros)
    else:
        for node_id in graph['nodes'].keys():
            members = graph['nodes'][node_id]
            nombres_miembros = [custom_tooltips_all[i] for i in members]
            airports.update(nombres_miembros)
        
    return airports

airports_DBSCAN = get_airports_from_graph(graph_all, 7)

airports_HDBSCAN = get_airports_from_graph(graph_all_)

airports_in_both = airports_DBSCAN & airports_HDBSCAN

print(f"Porcentaje de aeropuertos de DBSCAN {len(airports_in_both) / len(airports_DBSCAN) * 100}")
print(f"Porcentaje de aeropuertos de HDBSCAN {len(airports_in_both) / len(airports_HDBSCAN) * 100}")
# Out:
# Porcentaje de aeropuertos de DBSCAN 70.96774193548387
# Porcentaje de aeropuertos de HDBSCAN 88.0
